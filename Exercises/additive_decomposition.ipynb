# %%
from random import randrange
from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
import pandas as pd

# %% [markdown]
# # sample Additive Model

# %%
series = [i+randrange(10) for i in range(1, 100)]
result = seasonal_decompose(series, model='additive', freq=1)
result.plot()
pyplot.show()

# %% [markdown]
# # sample Multiplicative Model

# %%
series_mul = [i**2.0 for i in range(1, 100)]
result_mul = seasonal_decompose(series_mul, model='multiplicative', freq=1)
result_mul.plot()
pyplot.show()

# %%
# %cd
# Out:
# /home/trabeyauser

# %%
# %cd Projects/timeSeries/TimeSeries/data/
# Out:
# /home/trabeyauser/Projects/timeSeries/TimeSeries/data

# %%
series_air = pd.read_csv('airline-passengers.csv', header=0, index_col=0)
series_air.head(60)
series_air.plot()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm


series = read_csv('airline-passengers.csv', header=0, index_col=0)
result = sm.tsa.seasonal_decompose(series, model='multiplicative', freq=1)
result.plot()
pyplot.show()
